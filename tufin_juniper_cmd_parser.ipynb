# %%
import textfsm as tfm
import sys

# mount google drive to read files

from google.colab import drive
drive.mount("/content/drive", force_remount=True)

# import cmd lines generated by Juniper 
raw_file = "/content/drive/My Drive/Colab Notebooks/sample_rules_generated_by_Tufin.txt"
input_rawfile = open(raw_file, 'r')
raw_text_data = input_rawfile.read()
input_rawfile.close()

# read template file
template_file = "/content/drive/My Drive/Colab Notebooks/juniper_policy_tmpla.txt"
template = open(template_file, 'r')
re_table = tfm.TextFSM(template)

# create list from raw data 
fsm_rt_list = re_table.ParseText(raw_text_data)

# set up output file to be wriiten 
outfile_name = "/content/drive/My Drive/Colab Notebooks/juniper_policy_tuf18801.csv"
outfile = open(outfile_name, 'w')

# write headers
for item in re_table.header[0][0] :
 
     print(', '.join(re_table.header))
     outfile.write(': '.join(re_table.header))
outfile.write('\n')

# below will hang your IDE if the list is going to be huge comment it out!
print(fsm_rt_list)

counter = 0
index = 0

#write out data from list to file in csv format

for row in fsm_rt_list :
# modify following to present how your data will look like
     for row_data in row :
          stripped_data = str(row_data).strip("[").strip("]").replace("'","")
          outfile.write("{}: ".format(stripped_data))
     outfile.write("\n")
     counter += 1

print("Write {} records".format(counter)) 
# write all rows

outfile.close()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# PolicyName, FromZone, ToZone, Source, Destination, Port, Action, log, Desc
# [['Rule_1', 'core-c0-zaar2-ser-t2', 'trust-c3-zaar2-ser-t2', ['uat-server3-10.16.193.6', 'isd-lg3-10.16.193.35', 'isd-lg1-10.16.193.33', 'isd-lg2-10.16.193.34'], ['Host_10.18.35.110', 'Host_10.18.35.111'], ['tcp-1414-1420'], 'permit', 'session-init', 'Load Runner to POT eNAS MQ Servers'], ['Rule_1', 'trust-c1-zaaa-ser-t2', 'win-c0-zaaa-ser-t2', ['gfmp-1011-10.18.0.112'], ['Host_10.32.246.130', 'Host_10.32.246.128', 'Host_10.32.246.129'], ['tcp-1401', 'tcp-1499'], 'permit', 'session-init', 'DEV DB Scan Ports RCC'], ['Rule_2', 'trust-c1-zaaa-ser-t2', 'win-c0-zaaa-ser-t2', ['gfmp-1011-10.18.0.112'], ['Host_10.32.246.124', 'Host_10.32.246.125', 'Host_10.32.246.126', 'Host_10.32.246.127'], ['TCP_1452', 'tcp-1402'], 'permit', 'session-init', 'DEV DB VIP Ports RCC'], ['Rule_1', 'trust-c2-zaaa-ser-t2', 'win-c0-zaaa-ser-t2', ['gfmp-1021-10.18.0.176'], ['Host_10.32.246.130', 'Host_10.32.246.128', 'Host_10.32.246.129'], ['tcp-1401', 'tcp-1499'], 'permit', 'session-init', 'DEV DB Scan Ports RCC'], ['Rule_2', 'trust-c2-zaaa-ser-t2', 'win-c0-zaaa-ser-t2', ['gfmp-1021-10.18.0.176'], ['Host_10.32.246.124', 'Host_10.32.246.125', 'Host_10.32.246.126', 'Host_10.32.246.127'], ['TCP_1452', 'tcp-1402'], 'permit', 'session-init', 'DEV DB VIP Ports RCC'], ['Rule_1', 'trust-c2-zaae-ser-t2', 'win-c0-zaae-ser-t2', ['aixau2106st0144-10.18.8.135', 'aixau2106st0123-10.18.8.134'], ['Host_10.32.182.39', 'Host_10.32.182.38', 'Host_10.32.182.40'], ['tcp-1301', 'tcp-1399'], 'permit', 'session-init', 'TST Scan Ports WSDC'], ['Rule_2', 'trust-c2-zaae-ser-t2', 'win-c0-zaae-ser-t2', ['aixau2106st0144-10.18.8.135', 'aixau2106st0123-10.18.8.134'], ['Host_10.32.182.37', 'Host_10.32.182.34', 'Host_10.32.182.35', 'Host_10.32.182.36'], ['tcp-1302', 'tcp-1352-4hr-timeout'], 'permit', 'session-init', 'TST DB VIP Ports WSDC'], ['Rule_3', 'trust-c2-zaae-ser-t2', 'win-c0-zaae-ser-t2', ['aixau2106st0144-10.18.8.135', 'aixau2106st0123-10.18.8.134'], ['Host_10.32.246.130', 'Host_10.32.246.128', 'Host_10.32.246.129'], ['tcp-1301', 'tcp-1399'], 'permit', 'session-init', 'TST Scan Ports RCC'], ['Rule_4', 'trust-c2-zaae-ser-t2', 'win-c0-zaae-ser-t2', ['aixau2106st0144-10.18.8.135', 'aixau2106st0123-10.18.8.134'], ['Host_10.32.246.124', 'Host_10.32.246.125', 'Host_10.32.246.126', 'Host_10.32.246.127'], ['tcp-1302', 'tcp-1352-4hr-timeout'], 'permit', 'session-init', 'TST DB VIP Ports RCC'], ['Rule_1', 'trust-c2-zaaj-ser-t2', 'win-c0-zaaj-ser-t2', ['g-GFMP-wsdc-svp-pprod'], ['Host_10.32.246.130', 'Host_10.32.246.128', 'Host_10.32.246.129'], ['tcp-1201', 'tcp-1299'], 'permit', 'session-init', 'SVP DB Scan Ports RCC'], ['Rule_2', 'trust-c2-zaaj-ser-t2', 'win-c0-zaaj-ser-t2', ['g-GFMP-wsdc-svp-pprod'], ['Host_10.32.246.124', 'Host_10.32.246.125', 'Host_10.32.246.126', 'Host_10.32.246.127'], ['TCP_1252', 'tcp-1202'], 'permit', 'session-init', 'SVP DB VIP Ports RCC'], ['Rule_3', 'trust-c2-zaaj-ser-t2', 'win-c0-zaaj-ser-t2', ['g-GFMP-wsdc-svp-pprod'], ['Host_10.32.182.39', 'Host_10.32.182.38', 'Host_10.32.182.40'], ['tcp-1201', 'tcp-1299'], 'permit', 'session-init', 'SVP DB Scan Ports WSDC'], ['Rule_4', 'trust-c2-zaaj-ser-t2', 'win-c0-zaaj-ser-t2', ['g-GFMP-wsdc-svp-pprod'], ['Host_10.32.182.37', 'Host_10.32.182.34', 'Host_10.32.182.35', 'Host_10.32.182.36'], ['TCP_1252', 'tcp-1202'], 'permit', 'session-init', 'SVP DB VIP Ports WSDC'], ['Rule_5', 'trust-c2-zaaj-ser-t2', 'win-c0-zaaj-ser-t2', ['g-GFMP-wsdc-svp-pprod'], ['Host_10.32.182.130', 'Host_10.32.182.129', 'Host_10.32.182.128'], ['tcp-1201', 'tcp-1299'], 'permit', 'session-init', 'SVP DB Scan Ports WSDC'], ['Rule_6', 'trust-c2-zaaj-ser-t2', 'win-c0-zaaj-ser-t2', ['g-GFMP-wsdc-svp-pprod'], ['Host_10.32.182.124', 'Host_10.32.182.127', 'Host_10.32.182.126', 'Host_10.32.182.125'], ['TCP_1252', 'tcp-1202'], 'permit', 'session-init', 'SVP DB VIP Ports WSDC'], ['Rule_1', 'trust-c3-zaar2-ser-t2', 'core-c0-zaar2-ser-t2', ['Host_10.18.35.110', 'Host_10.18.35.111'], ['uat-server3-10.16.193.6', 'isd-lg3-10.16.193.35', 'isd-lg1-10.16.193.33', 'isd- ...
# Write 24 records

# %%
pip install textfsm
# Out:
# Collecting textfsm
#   Downloading https://files.pythonhosted.org/packages/a1/0d/a1b490503545b3b4600b965eae5d44cc2b6ce27cfb44f4debc563dbb56d3/textfsm-0.4.1.tar.gz
# Building wheels for collected packages: textfsm
#   Building wheel for textfsm (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/e8/53/bc/dde37586dcf79060801e151dd4a137d98e64d0deca46eb19ba
# Successfully built textfsm
# Installing collected packages: textfsm
# Successfully installed textfsm-0.4.1
